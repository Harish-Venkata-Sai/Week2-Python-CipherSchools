# %%
#data structures

# %%
a = 5
print("value of a is {}")
# Out:
# value of a is {}

# %%
a, b, c, d = 1, 2, 3, 4

"a = {2}, b = {1}, c = {0}".format(c, b, a)
# Out:
# 'a = 1, b = 2, c = 3'

# %%
name = "harish"
company = "amazon"
"name = {name} company = {company}".format(name = name, company = company)
# Out:
# 'name = harsha company = amazon'

# %%
print(f"name = {name}")
# Out:
# name = harsha

# %%
len(r"a/nb")
# Out:
# 4

# %%
"      harsha.      ".strip()
# Out:
# 'harsha.'

# %%
"1, 2, 3, 4, 5".strip()
# Out:
# '1, 2, 3, 4, 5'

# %%
"harsha vardhan".replace("a","z")
# Out:
# 'hzrshz vzrdhzn'
