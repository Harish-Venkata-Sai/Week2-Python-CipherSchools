# %%
# lambda expressions

# %%
lambda a, b: a + b
# Out:
# <function __main__.<lambda>(a, b)>

# %%
print("Hello World")
# Out:
# Hello World

# %%
show = print
show("something")
# Out:
# something

# %%
names = ["harish", "venkata", "sai"]
for name in names:
  print(name)
# Out:
# Running cells with 'Python 3.10.8 64-bit (microsoft store)' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/haris/AppData/Local/Microsoft/WindowsApps/python3.10.exe -m pip install ipykernel -U --force-reinstall'

# %%
names = ["harish", "venkata", "sai"]
for name in enumerate(names):
  print(name)
# Out:
# (0, 'harsha')
# (1, 'sai')
# (2, 'teja')

# %%
int a[] = {1, 2, 3}

# %%
a = 5
b = 9
